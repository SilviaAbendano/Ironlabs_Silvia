# %% [markdown]
# # Holidays

# %% [markdown]
# ## Index:
# * [Holidays preference](#first-bullet)
# * [Where would I like to travel next?](#second-bullet)

# %% [markdown]
# ### My holiday preferences is to get to know new places, go to the beach, to the mountains but also to go to my favorite city: Barcelona!

# %% [markdown]
# # Holidays preference <a class="anchor" id="first-bullet"></a>

# %%
name = input("Enter your name ")
# Out:
# Enter your name Silvia

# %% [markdown]
# ![WhatsApp%20Image%202021-08-28%20at%2016.44.47.jpeg](attachment:WhatsApp%20Image%202021-08-28%20at%2016.44.47.jpeg)

# %% [markdown]
# # Where would I like to travel next?  <a class="anchor" id="second-bullet"></a>

# %%
holidaypreference = input("Where would you to travel for your next vacation? ")
# Out:
# Where would you to travel for your next vacation? Nepal

# %% [markdown]
# ![Everest.jpeg](attachment:Everest.jpeg)

# %% [markdown]
# **Top 3** things I would like to do there:
#
# + ***Hiking***
# + ***Eat Nepali food***
# + ***Enjoy the nature***

# %% [markdown]
# [link](https://www.youtube.com/watch?v=usuubU_0QCI)

# %% [markdown]
# For this lab I have mainly used the input function to enter name and next vacation preference
